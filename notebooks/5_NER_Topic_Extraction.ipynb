# %% [markdown]
# # 6. Topic extraction from NER
# In this notebook we are going to perform a selection of topics from the entities recognized in each article. The process will be as follows:
# * The Named Entity Recognizer object created in notebook _4_Named_Entity_Recognition_ will be loaded.
# * The list of entities for a given text will be retrieved.
# * After we have the list of entities, they will be linked to Wikidata.
# * From the list of linked entities, we will create a graph with the Wikidata entities obtained by expanding some of their properties.
# * Once the graph has been obtained, we will apply centrality algotihms to select the most representative entities from  it, which will serve as topics for the text.

# %% [markdown]
# ## Setup

# %%
# %run __init__.py

logger.setLevel(logging.INFO)
# Out:
# INFO:root:Starting logger

# %%
from bokeh.io import output_notebook

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Loading the data
# We will start by loading the agriculture dataframe created in notebook 2. After that, we will select the last article to demonstrate what the main data workflow will be:

# %%
import pandas as pd

DF_FILE_PATH = os.path.join(NOTEBOOK_2_RESULTS_DIR, 'protocols_dataframe.pkl')

df = pd.read_pickle(DF_FILE_PATH)
protocols = df['full_text_cleaned'].values

# %%
text = protocols[-1]

# %% [markdown]
# ## Loading the NER model
# The named entity recognition model created in notebook 4 will now be loaded and used to obtain the entities of the article:

# %%
import en_core_sci_lg

from herc_common.text import NamedEntityRecognizer
from collections import Counter
import en_core_sci_lg

ner = NamedEntityRecognizer(en_core_sci_lg, min_entity_counts=2)

# %%
nlp = en_core_sci_lg.load()
entities = ner.transform([text])
entities[0][:10]
# Out:
# ['supernatant',
#  'OMVs',
#  'bacteria',
#  'E. coli',
#  'volume',
#  'culture',
#  'OMV',
#  'Escherichia coli',
#  'culture supernatant',
#  'LB broth']

# %% [markdown]
# ## Entity linking
# Now, we will be making use of the WikidataEntityLinker class to obtain the Wikidata URI of each entity recognized before:

# %%
from herc_common.entity_linking import WikidataEntityLinker

linker = WikidataEntityLinker()
linked_entities = linker.fit_transform(entities)
linked_entities[0][:5]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# [('supernatant', 'http://www.wikidata.org/entity/Q40307811'),
#  ('OMVs', 'http://www.wikidata.org/entity/Q2029890'),
#  ('bacteria', 'http://www.wikidata.org/entity/Q10876'),
#  ('E. coli', 'http://www.wikidata.org/entity/Q25419'),
#  ('volume', 'http://www.wikidata.org/entity/Q39297')]

# %% [markdown]
# ## Building the graph
# After each entity has been linked to Wikidata, w:e will begin exploring their neighbourhood in the knowledge graph to obtain a list of candidates for our final topics

# %%
from herc_common.graph import WikidataGraphBuilder

graph_builder = WikidataGraphBuilder(max_hops=2)
entity_graph = graph_builder.build_graph(linked_entities[0])
# Out:
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.

# %%
from bokeh.io import show
from bokeh.layouts import gridplot

from herc_common.bokeh_utils import build_graph_plot

plot = build_graph_plot(entity_graph, f"Linked entities graph")
show(plot)
# Out:
#   <div class="bk-root" id="11b54a44-ea86-4ab4-a30e-fca765f92ddf" data-root-id="1039"></div>

# %% [markdown]
# Since the graph from above is not completely connected, we will be obtaining the largest connected subgraph:

# %%
from herc_common.graph import get_largest_connected_subgraph

connected_entity_subgraph = get_largest_connected_subgraph(entity_graph)

plot = build_graph_plot(connected_entity_subgraph, f"Linked entities graph")
show(plot)
# Out:
#   <div class="bk-root" id="e40dbacb-d494-4643-a7ad-6ffe0dd113db" data-root-id="1223"></div>

# %% [markdown]
# Now that we have the Wikidata graph obtained from our initial list of entities from the text, we will be trying out a list of centrality algorithms to obtain the top 9 entities that represent the text. These entities can be seen as potential topics for the publication:

# %%
import networkx.algorithms as nxa

from herc_common.graph import get_centrality_algorithm_results

def try_centrality_algorithms(g, algorithms, stop_uris, top_n=9):
    for (algorithm, name) in algorithms:
        print(f'Algorithm: {name}')
        result = get_centrality_algorithm_results(g, algorithm, stop_uris, top_n)
        print(f"Topics:", result)
        print()
        
algorithms = [
    (nxa.centrality.information_centrality, "Information centrality"),
    (nxa.centrality.eigenvector_centrality_numpy, "Eigenvector centrality"),
    (nxa.centrality.closeness_centrality, "Closeness centrality"),
    (nxa.centrality.betweenness_centrality, "Betweenness centrality"),
    (nxa.centrality.load_centrality, "Load centrality")
]

stop_uris = ['Q4167836', 'Q11862829', 'Q13442814',
             'Q17339814', 'Q24017414', 'Q4671286',
             'Q47154513']
try_centrality_algorithms(connected_entity_subgraph,
                          algorithms,
                          stop_uris)
# Out:
# Algorithm: Information centrality
# Topics: [({'qid': 'Q3009579', 'desc': 'branch of life science that deals with the study of cells in terms of structure, function and chemistry', 'label': 'cytology', 'n': 1, 'node_color': '#abdda4'}, 0.003980929376987619), ({'qid': 'Q7868', 'desc': 'the basic structural and functional unit of all organisms', 'label': 'cell', 'n': 0, 'node_color': '#2b83ba'}, 0.003915145033214796), ({'qid': 'Q40397', 'desc': 'cellular organizational level intermediate between cells and a complete organism; cells that are grouped together with a common function', 'label': 'tissue', 'n': 1, 'node_color': '#abdda4'}, 0.0037279190975551342), ({'qid': 'Q27062218', 'desc': '', 'label': 'multicellular structure', 'n': 2, 'node_color': '#fdae61'}, 0.0036077635707123593), ({'qid': 'Q23404', 'desc': 'science of humanity', 'label': 'anthropology', 'n': 1, 'node_color': '#abdda4'}, 0.003607534531879732), ({'qid': 'Q28845870', 'desc': 'component of the biological system', 'label': 'biological component', 'n': 2, 'node_color': '#fdae61'}, 0.003602122421876663), ({'qid': 'Q189118', 'desc': 'classification used to distinguish between morphologically or phenotypically distinct cell forms within a species', 'label': 'cell type', 'n': 1, 'node_color': '#abdda4'}, 0.0035709125123658952), ({'qid': 'Q20088819', 'desc': 'biology', 'label': 'group of cells', 'n': 2, 'node_color': '#fdae61'}, 0.003533844326036697), ({'qid': 'Q4936952', 'desc': "entity with a single connected inherent 3D shape that's created by coordinated expression of the organism's own DNA", 'label': 'anatomical structure', 'n': 2, 'node_color': '#fdae61'}, 0.003521083251477222)]
#
# Algorithm: Eigenvector centrality
# Topics: [({'qid': 'Q7868', 'desc': 'the basic structural and functional unit of all organisms', 'label': 'cell', 'n': 0, 'node_color': '#2b83ba'}, 0.49674375229589407), ({'qid': 'Q40397', 'desc': 'cellular organizational level intermediate between cells and a complete organism; cells that are grouped together with a common function', 'label': 'tissue', 'n': 1, 'node_color': '#abdda4'}, 0.45715057921098845), ({'qid': 'Q27062218', 'desc': '', 'label': 'multicellular structure', 'n': 2, 'node_color': '#fdae61'}, 0.34214569160371977), ({'qid': 'Q20088819', 'desc': 'biology', 'label': 'group of cells', 'n': 2, 'node_color': '#fdae61'}, 0.31299063285787765), ({'qid': 'Q28845870', 'desc': 'component of the biological system', 'label': 'biological component', 'n': 2, 'node_color': '#fdae61'}, 0.29280789366955773), ({'qid': 'Q4936952', 'desc': "entity with a single connected inherent 3D shape that's created by coordinated expression of the organism's own DNA", 'label': 'anatomical structure', 'n': 2, 'node_color': '#fdae61'}, 0.22818110989221804), ({'qid': 'Q189118', 'desc': 'classification used to distinguish between morphologically or phenotypically distinct cell forms within a species', 'label': 'cell type', 'n': 1, 'node_color': '#abdda4'}, 0.1977814202330012), ({'qid': 'Q5058355', 'desc': 'component of a cell', 'label': 'cellular component', 'n': 1, 'node_color': '#abdda4'}, 0.1806887993896594), ({'qid': 'Q3009579', 'desc': 'branch of life science that deals with the study of cells in terms of structure, function and chemistry', 'label': 'cytology', 'n': 1, 'node_color': '#abdda4'}, 0.14638462724970613)]
#
# Algorithm: Closeness centrality
# Topics: [({'qid': 'Q3009579', 'desc': 'branch of life science that deals with the study of cells in terms of structure, function and chemistry', 'label': 'cytology', 'n': 1, 'node_color': '#abdda4'}, 0.26129032258064516), ({'qid': 'Q7868', 'desc': 'the basic structural and functional unit of all organisms', 'label': 'cell', 'n': 0, 'node_color': '#2b83ba'}, 0.25471698113207547), ({'qid': 'Q23404', 'desc': 'science of humanity', 'label': 'anthropology', 'n': 1, 'node_color': '#abdda4'}, 0.24107142857142858), ({'qid': 'Q189118', 'desc': 'classification used to distinguish between morphologically or phenotypically distinct cell forms within a species', 'label': 'cell type', 'n': 1, 'node_color': '#abdda4'}, 0.225), ({'qid': 'Q11042', 'desc': "society's way of life within anthropology", 'label': 'culture', 'n': 0, 'node_color': '#2b83ba'}, 0.22131147540983606), ({'qid': 'Q28598684', 'desc': '', 'label': 'branch of biology', 'n': 2, 'node_color': '#fdae61'}, 0.2154255319148936), ({'qid': 'Q1143546', 'desc': 'academic field of critical theory and literary criticism', 'label': 'cultural studies', 'n': 2, 'node_color': '#fdae61'}, 0.21428571428571427), ({'qid': 'Q40397', 'desc': 'cellular organizational level intermediate between cells and a complete organism; cells that are grouped together with a common function', 'label': 'tissue', 'n': 1, 'node_color': '#abdda4'}, 0.2131578947368421), ({'qid': 'Q28845870', 'desc': 'component of the biological system', 'label': 'biological component', 'n': 2, 'node_color': '#fdae61'}, 0.2109375)]
#
# Algorithm: Betweenness centrality
# Topics: [({'qid': 'Q3009579', 'desc': 'branch of life science that deals with the study of cells in terms of structure, function and chemistry', 'label': 'cytology', 'n': 1, 'node_color': '#abdda4'}, 0.5853909465020577), ({'qid': 'Q7868', 'desc': 'the basic structural and functional unit of all organisms', 'label': 'cell', 'n': 0, 'node_color': '#2b83ba'}, 0.5784722222222223), ({'qid': 'Q23404', 'desc': 'science of humanity', 'label': 'anthropology', 'n': 1, 'node_color': '#abdda4'}, 0.5169753086419754), ({'qid': 'Q11042', 'desc': "society's way of life within anthropology", 'label': 'culture', 'n': 0, 'node_color': '#2b83ba'}, 0.40092592592592596), ({'qid': 'Q189118', 'desc': 'classification used to distinguish between morphologically or phenotypically distinct cell forms within a species', 'label': 'cell type', 'n': 1, 'node_color': '#abdda4'}, 0.3651748971193413), ({'qid': 'Q16521', 'desc': 'group of one or more organism(s), which a taxonomist adjudges to be a unit', 'label': 'taxon', 'n': 1, 'node_color': '#abdda4'}, 0.3037037037037037), ({'qid': 'Q1143546', 'desc': 'academic field of critical theory and literary criticism', 'label': 'cultural studies', 'n': 2, 'node_color': '#fdae61'}, 0.15632716049382717), ({'qid': 'Q28598684', 'desc': '', 'label': 'branch of biology', 'n': 2, 'node_color': '#fdae61'}, 0.1244855967078189), ({'qid': 'Q5193405', 'desc': 'human rights related to culture and art', 'label': 'cultural rights', 'n': 1, 'node_color': '#abdda4'}, 0.12037037037037036)]
#
# Algorithm: Load centrality
# Topics: [({'qid': 'Q3009579', 'desc': 'branch of life science that deals with the study of cells in terms of structure, function and chemistry', 'label': 'cytology', 'n': 1, 'node_color': '#abdda4'}, 0.5858796296296298), ({'qid': 'Q7868', 'desc': 'the basic structural and functional unit of all organisms', 'label': 'cell', 'n': 0, 'node_color': '#2b83ba'}, 0.5767296810699591), ({'qid': 'Q23404', 'desc': 'science of humanity', 'label': 'anthropology', 'n': 1, 'node_color': '#abdda4'}, 0.5168981481481482), ({'qid': 'Q11042', 'desc': "society's way of life within anthropology", 'label': 'culture', 'n': 0, 'node_color': '#2b83ba'}, 0.40084876543209874), ({'qid': 'Q189118', 'desc': 'classification used to distinguish between morphologically or phenotypically distinct cell forms within a species', 'label': 'cell type', 'n': 1, 'node_color': '#abdda4'}, 0.3651748971193414), ({'qid': 'Q16521', 'desc': 'group of one or more organism(s), which a taxonomist adjudges to be a unit', 'label': 'taxon', 'n': 1, 'node_color': '#abdda4'}, 0.3037037037037037), ({'qid': 'Q1143546', 'desc': 'academic field of critical theory and literary criticism', 'label': 'cultural studies', 'n': 2, 'node_color': '#fdae61'}, 0.1564043209876543), ({'qid': 'Q28598684', 'desc': '', 'label': 'branch of biology', 'n': 2, 'node_color': '#fdae61'}, 0.125951646090535), ({'qid': 'Q5193405', 'desc': 'human rights related to culture and art', 'label': 'cultural rights', 'n': 1, 'node_color': '#abdda4'}, 0.12037037037037036)]

# %% [markdown]
# ## Setting up the pipeline
# Now that we have seen the main data flow, we will build the final pipeline. This pipeline will receive a list of texts, and return 7 potential topics for each text by executing the steps described above:

# %%
from sklearn.pipeline import Pipeline

from herc_common.topic import TopicLabeller


topic_extractor = TopicLabeller(graph_builder, nxa.centrality.closeness_centrality,
                                num_labels_per_topic=7, stop_uris=stop_uris)
topic_pipe = Pipeline([('ner', ner),
                       ('entity_linker', linker),
                       ('topic_extractor', topic_extractor)])

# %% [markdown]
# The pipeline will be now saved for later use in the final system:

# %%
from herc_common.utils import save_object

PIPE_OUTPUT_FILE_NAME = "topic_extraction_from_ner_pipe.pkl"

save_object(topic_pipe, os.path.join(NOTEBOOK_5_RESULTS_DIR, PIPE_OUTPUT_FILE_NAME))

# %% [markdown]
# ### Obtaining the topics
# Before finishing with this notebook, we will be obtaining the list of inferred topics for each one of the articles from the agriculture dataset. To do so, we just have to call the _fit_transform_ method of our pipeline:

# %%
results = topic_pipe.fit_transform(protocols)
results[:5]
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# [[Topic(label='interaction science', qid='Q97008347', desc='scientific discipline', score=0.41148325358851673, t_type='ner'),
#   Topic(label='communication medium', qid='Q340169', desc='storage and delivering agent of information or data', score=0.34959349593495936, t_type='ner'),
#   Topic(label='communication', qid='Q11024', desc='act of conveying intended meanings from one entity or group to another through the use of mutually understood signs and rules', score=0.3333333333333333, t_type='ner'),
#   Topic(label='media history', qid='Q50636', desc='study of the mass media and technomedia in their historical development', score=0.3173431734317343, t_type='ner'),
#   Topic(label='cytology', qid='Q3009579', desc='branch of life science that deals with the study of cells in terms of structure, function and chemistry', score=0.3173431734317343, t_type='ner'),
#   Topic(label='science', qid='Q336', desc='Systematic enterprise that builds and organizes knowledge', score=0.3049645390070922, t_type='ner'),
#   Topic(label='communication studies', qid='Q14623843', desc='academic field that deals with processes of communication', score=0.3006993006993007, t_type='ner')],
#  [Topic(label='chemical compound', qid='Q11173', desc='pure chemical substance consisting of two or more different chemical elements', score=0.21055825242718446, t_type='ner'),
#   Topic(label='family of protein complexes', qid='Q78155096', desc='species-independent set of protein complexes with a common characteristic or origin', score=0.20928829915560918, t_type='ner'),
#   Topic(label='glucose', qid='Q37525', desc='simple sugar', score=0.20034642032332564, t_type='ner'),
#   Topic(label='blood plasma', qid='Q79749', desc='liquid component of blood', score=0.19942528735632184, t_type='ner'),
#   Topic(label='antibody', qid='Q79460', desc='immune system protein', score=0.19794637763833428, t_type='ner'),
#   Topic(label='cell type', qid='Q189118', desc='classification used to distinguish between morphologically or phenotypically distinct cell forms within a species', score=0.1946158160403814, t_type='ner'),
#   Topic(label='blood', qid='Q7873', desc='Organic fluid which transports nutrients throughout the organism', score=0.19407158836689037, t_type='ner')],
#  [Topic(label='chemical compound', qid='Q11173', desc='pure chemical substance consisting of two or more different chemical elements', score=0.2906110283159464, t_type='ner'),
#   Topic(label='chemistry', qid='Q2329', desc='branch of physical science concerned with the composition, structure and properties of matter', score=0.276792051100071, t_type='ner'),
#   Topic(label='protein', qid='Q8054', desc='biological molecule consisting of chains of amino acid residues', score=0.26841018582243636, t_type='ner'),
#   Topic(label='chemical substance', qid='Q79529', desc='matter of constant composition best characterized by the entities (molecules, formula units, atoms) it is composed of and characterized by physical properties like density', score=0.2613941018766756, t_type='ner'),
#   Topic(label='ethanol', qid='Q153', desc='chemical compound', score=0.26104417670682734, t_type='ner'),
#   Topic(label='hydrogen peroxide', qid='Q171877', desc='chemical compound', score=0.25473546701502287, t_type='ner'),
#   Topic(label='ribonucleoprotein', qid='Q417662', desc='macromolecular complex containing both protein and RNA molecules.', score=0.24208566108007448, t_type='ner')],
#  [Topic(label='ribonucleoprotein', qid='Q417662', desc='macromolecular complex containing both protein and RNA molecules.', score=0.1885354539430086, t_type='ner'),
#   Topic(label='cellular component', qid='Q5058355', desc='component of a cell', score=0.1820217530390275, t_type='ner'),
#   Topic(label='cell', qid='Q7868', desc='the basic structural and functional unit of all organisms', score=0.18149920255183413, t_type='ner'),
#   Topic(label='ribonucleoprotein granule', qid='Q21106243', desc='A non-membranous macromolecular complex containing proteins and translationally silenced mRNAs. RNA granules contain proteins that control the localization, stability, and translation of their RNA cargo. Different types of RNA granules (RGs) exist, d', score=0.18138348740835192, t_type='ner'),
#   Topic(label='chemical compound', qid='Q11173', desc='pure chemical substance consisting of two or more different chemical elements', score=0.17994939911448452, t_type='ner'),
#   Topic(label='RNA', qid='Q11053', desc='family of large biological molecules', score=0.17938209331651955, t_type='ner'),
#   Topic(label='cell type', qid='Q189118', desc='classification used to distinguish between morphologically or phenotypically distinct cell forms within a species', score=0.1790997796663519, t_type='ner')],
#  [Topic(label='chemical compound', qid='Q11173', desc='pure chemical substance consisting of two or more different chemical elements', score=0.2577777777777778, t_type='ner'),
#   Topic(label='glucose', qid='Q37525', desc='simple sugar', score=0.24602332979851538, t_type='ner'),
#   Topic(label='carbon dioxide', qid='Q1997', desc='chemical compound', score=0.228009828009828, t_type='ner'),
#   Topic(label='biological process', qid='Q2996394', desc='process specifically pertinent to the functioning of integrated living units', score=0.22623110677718186, t_type='ner'),
#   Topic(label='sirolimus', qid='Q32089', desc='pharmaceutical drug', score=0.22437137330754353, t_type='ner'),
#   Topic(label="sucrose catabolic process via 3'-ketosucrose", qid='Q22281809', desc="The chemical reactions and pathways resulting in the breakdown of sucrose, which proceeds via the conversion of sucrose to 3'-ketosucrose. 3'-ketosucrose is hydrolyzed to 3-ketoglucose and fructose, and the 3-ketoglucose is then be converted to gluco", score=0.21938534278959812, t_type='ner'),
#   Topic(label='glucose catabolic process to pyruvate', qid='Q22275633', desc='The chemical reactions and pathways resulting in the breakdown of glucose, with the production of pyruvate.', score=0.21938534278959812, t_type='ner')]]

# %% [markdown]
# ### Saving the results
# Now, we will be merging the results into our agriculture dataframe, and save the results to a CSV file. This file will contain the id and title of each article, with their respective topics inferred by the system:

# %%
NEW_COL_NAME = 'topics_from_ner'

df[NEW_COL_NAME] = ['\n'.join([f"{topic.label}, {topic.score:.4f}" for topic in result])
                        for result in results]
df.head()
# Out:
#    pr_id                                              title  \
# 0   e100                        Scratch Wound Healing Assay
# 1  e1029                                ADCC Assay Protocol
# 2  e1072        Catalase Activity Assay in Candida glabrata
# 3  e1077           RNA Isolation and Northern Blot Analysis
# 4  e1090  Flow Cytometric Analysis of Autophagic Activit...
#
#                                             abstract  \
# 0  The scratch wound healing assay has been widel...
# 1  Antibody-dependent cell-mediated cytotoxicity ...
# 2  Commensal and pathogenic fungi are exposed to ...
# 3  The northern blot is a technique used in molec...
# 4  Flow cytometry allows very sensitive and relia...
#
#                                            materials  \
# 0  Human MDA-MB-231 cell line (ATCC, catalog numb...
# 1  Raji cells (ATCC)|A/California/04/2009 (H1N1) ...
# 2  Yeast strains \nNote: BG14 was used as the C. ...
# 3  Vero cells (kidney epithelial cells extracted ...
# 4  Cells lines of interest (HepG2, HUH7, CMK, K56...
#
#                                            procedure  \
# 0  Grow cells in DMEM supplemented with 10% FBS.|...
# 1  Preperation of Target Cells\n\n\t\t\n\n\n\t\t\...
# 2  Preparation of total soluble extracts\n\t\t\n\...
# 3  RNA extraction\n\t\t\n\n\t\t\t\tCells were see...
# 4  Maintain cells under standard tissue culture c...
#
#                                            equipment background  \
# 0  BD Falcon 24-well tissue culture plate (Fisher...
# 1  Round bottomed 96-well plate|Temperature contr...
# 2  Orbital incubator shaker|Microfuge tubes|50 ml...
# 3  100 mm cell culture dishes (Corning, catalog n...
# 4  37 °C, 5% CO2 humidified incubator|Centrifuge|...
#
#                                           categories  \
# 0  Cancer Biology|Invasion & metastasis|Cell biol...
# 1  Immunology|Immune cell function|Cytotoxicity|C...
# 2  Microbiology|Microbial biochemistry|Protein|Ac...
# 3  Microbiology|Microbial genetics|RNA|RNA extrac...
# 4  Microbiology|Antimicrobial assay|Autophagy ass...
#
#                                              authors  \
# 0                                       Yanling Chen
# 1  Vikram  Srivastava|Zheng  Yang|Ivan  Fan  Ngai...
# 2  Emmanuel  Orta-Zavalza|Marcela  Briones-Martin...
# 3  Ying Liao|To Sing Fung|Mei Huang|Shouguo Fang|...
# 4  Metodi  Stankov|Diana  Panayotova-Dimitrova|Ma...
#
#                                            full_text  \
# 0  Scratch Wound Healing Assay. The scratch wound...
# 1  ADCC Assay Protocol. Antibody-dependent cell-m...
# 2  Catalase Activity Assay in Candida glabrata. C...
# 3  RNA Isolation and Northern Blot Analysis. The ...
# 4  Flow Cytometric Analysis of Autophagic Activit...
#
#                                    full_text_cleaned  num_chars_text  \
# 0  Scratch Wound Healing Assay. The scratch wound...            2583
# 1  ADCC Assay Protocol. Antibody-dependent cell-m...            3824
# 2  Catalase Activity Assay in Candida glabrata. C...            4207
# 3  RNA Isolation and Northern Blot Analysis. The ...            6890
# 4  Flow Cytometric Analysis of Autophagic Activit...            5890
#
#                                      topics_from_ner
# 0  interaction science, 0.4115\ncommunication med...
# 1  chemical compound, 0.2106\nfamily of protein c...
# 2  chemical compound, 0.2906\nchemistry, 0.2768\n...
# 3  ribonucleoprotein, 0.1885\ncellular component,...
# 4  chemical compound, 0.2578\nglucose, 0.2460\nca...

# %%
results_df = df[['pr_id', 'title', NEW_COL_NAME]]
results_df.head()
# Out:
#    pr_id                                              title  \
# 0   e100                        Scratch Wound Healing Assay
# 1  e1029                                ADCC Assay Protocol
# 2  e1072        Catalase Activity Assay in Candida glabrata
# 3  e1077           RNA Isolation and Northern Blot Analysis
# 4  e1090  Flow Cytometric Analysis of Autophagic Activit...
#
#                                      topics_from_ner
# 0  interaction science, 0.4115\ncommunication med...
# 1  chemical compound, 0.2106\nfamily of protein c...
# 2  chemical compound, 0.2906\nchemistry, 0.2768\n...
# 3  ribonucleoprotein, 0.1885\ncellular component,...
# 4  chemical compound, 0.2578\nglucose, 0.2460\nca...

# %%
OUTPUT_FILE_NAME = "df_with_ner_topics.csv"

results_df.to_csv(os.path.join(NOTEBOOK_5_RESULTS_DIR, OUTPUT_FILE_NAME), index=False)
