# %% [markdown]
# # 4. Topic Labelling
# In this notebook we will be infering a label for each one of the topics obtained in the Topic Modelling notebook. The main process will be divided as follows:
# * We will begin by linking to [Wikidata](https://www.wikidata.org/wiki/Wikidata:Main_Page) each one of the terms that belong to each topic. (Entity linking)
# * After the entity linking step, we will generate a Graph with the neighbour nodes of each starting term by traversing their Wikidata information based on a set of properties to expand.
# * Once a graph is built for each topic, we will remove isolated subgraphs from them to obtain the main connected subgraph of each one.
# * We will apply a set of centrality algorithms to obtain the entity from Wikidata which best represents the topic subgraph. This node will be used as a label for the topic.
# * Finally, the topic labels will be added to the final model, which will be serialized for further use in the following notebooks.

# %% [markdown]
# ## Setup
# As always, we will begin by loading a set of constants and initializing the logging system. Since we will be using Bokeh in this notebook, we will configure it to output the results in the Jupyter notebook:

# %%
# %run __init__.py
# Out:
# INFO:root:Starting logger

# %%
from bokeh.io import output_notebook

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
import pandas as pd

DF_FILE_PATH = os.path.join(NOTEBOOK_2_RESULTS_DIR, 'protocols_dataframe.pkl')

df = pd.read_pickle(DF_FILE_PATH)
protocols = df['full_text_cleaned'].values

# %% [markdown]
# ## Entity linking

# %% [markdown]
# ### Using the entity linking class
# An entity linking class has been defined in the _entity_linking.py_ module of the _src_ directory. This class will link the given words to their Wikidata entity by using the [wbsearchentities](https://www.wikidata.org/w/api.php?action=help&modules=wbsearchentities) modules from the MediaWiki API:

# %%
from herc_common.entity_linking import WikidataEntityLinker

entity_linker = WikidataEntityLinker()
res = entity_linker.link_entity('agroforestry')
res
# Out:
# ('agroforestry', 'http://www.wikidata.org/entity/Q397350')

# %% [markdown]
# ### Linking each topic's term to Wikidata
# In the following cells we are going to load the lda model trained on the Agriculture dataset, obtain the term distribution of each topic, and link each term to Wikidata. We will start by loading both the LDA pipeline and the document term matrix with the term frequency:

# %%
from herc_common.utils import load_object

lda_agriculture_pipe_filename = "protocols_lda_model.pkl"
dtm_tf_filename = "protocols_dtm_tf.pkl"

lda_pipe = load_object(os.path.join(NOTEBOOK_3_RESULTS_DIR, lda_agriculture_pipe_filename))
dtm_tf = load_object(os.path.join(NOTEBOOK_3_RESULTS_DIR, dtm_tf_filename))

# %% [markdown]
# In order to obtain the list of terms for each topic, we are going to make use of the _get\_topic\_terms\_by\_relevance_ function to obtain a list of more relevant terms for each topic (see [Sievert & Shirley](https://nlp.stanford.edu/events/illvi2014/papers/sievert-illvi2014.pdf) for more information).

# %%
from herc_common.utils import get_topic_terms_by_relevance

def link_topic_terms(entity_linker, model, vectorizer,
                     dtm_tf, n_top_words, lambda_=0.6):
    res = []
    topic_terms = get_topic_terms_by_relevance(model, vectorizer, dtm_tf,
                                               n_top_words, lambda_)
    return [[entity_linker.link_entity(entity) for entity in topic]
            for topic in topic_terms]

# %% [markdown]
# Finally, we can make used of the function defined above to link each term to Wikidata. The output of the following cell will be a 2D array, with the first dimension corresponding to each topic, and the second one consisting on tuples containing the pair ('term', 'wikidata_uri') for every term of the topic:

# %%
linked_terms = link_topic_terms(entity_linker, lda_pipe.named_steps['model'],
                                lda_pipe.named_steps['vectorizer'], dtm_tf, 
                                n_top_words=10, lambda_=0.8)
linked_terms
# Out:
# [[('nematode', 'http://www.wikidata.org/entity/Q5185'),
#   ('specimen', 'http://www.wikidata.org/entity/Q2114846'),
#   ('sample', 'http://www.wikidata.org/entity/Q485146'),
#   ('activity', 'http://www.wikidata.org/entity/Q1914636'),
#   ('tissue', 'http://www.wikidata.org/entity/Q40397'),
#   ('sod', 'http://www.wikidata.org/entity/Q525728'),
#   ('image', 'http://www.wikidata.org/entity/Q478798'),
#   ('section', 'http://www.wikidata.org/entity/Q3181348'),
#   ('microscopy', 'http://www.wikidata.org/entity/Q27724680'),
#   ('bone', 'http://www.wikidata.org/entity/Q265868')],
#  [('cell', 'http://www.wikidata.org/entity/Q7868'),
#   ('medium', 'http://www.wikidata.org/entity/Q340169'),
#   ('day', 'http://www.wikidata.org/entity/Q573'),
#   ('plate', 'http://www.wikidata.org/entity/Q57216'),
#   ('wash', 'http://www.wikidata.org/entity/Q1437299'),
#   ('dish', 'http://www.wikidata.org/entity/Q57216'),
#   ('device', 'http://www.wikidata.org/entity/Q3966'),
#   ('pipette', 'http://www.wikidata.org/entity/Q163373'),
#   ('differentiation', 'http://www.wikidata.org/entity/Q4847340'),
#   ('culture', 'http://www.wikidata.org/entity/Q11042')],
#  [('protein', 'http://www.wikidata.org/entity/Q8054'),
#   ('fraction', 'http://www.wikidata.org/entity/Q1134686'),
#   ('buffer', 'http://www.wikidata.org/entity/Q208465'),
#   ('gradient', 'http://www.wikidata.org/entity/Q173582'),
#   ('membrane', 'http://www.wikidata.org/entity/Q226697'),
#   ('pellet', 'http://www.wikidata.org/entity/Q527229'),
#   ('tube', 'http://www.wikidata.org/entity/Q1318740'),
#   ('cell', 'http://www.wikidata.org/entity/Q7868'),
#   ('total', 'http://www.wikidata.org/entity/Q154037'),
#   ('lysate', 'http://www.wikidata.org/entity/Q21562212')],
#  [('gene', 'http://www.wikidata.org/entity/Q7187'),
#   ('sequence', 'http://www.wikidata.org/entity/Q133250'),
#   ('soybean', 'http://www.wikidata.org/entity/Q57428103'),
#   ('homologous', 'http://www.wikidata.org/entity/Q12715503'),
#   ('syntenic', 'http://www.wikidata.org/entity/Q36199273'),
#   ('tumorsphere', 'http://www.wikidata.org/entity/Q39413649'),
#   ('bean', 'http://www.wikidata.org/entity/Q379813'),
#   ('common', 'http://www.wikidata.org/entity/Q286022'),
#   ('alignment', 'http://www.wikidata.org/entity/Q2579409'),
#   ('duplication', 'http://www.wikidata.org/entity/Q746284')],
#  [('pathological', 'http://www.wikidata.org/entity/Q1456138'),
#   ('optiprep', 'http://www.wikidata.org/entity/Q55488779'),
#   ('cushion', 'http://www.wikidata.org/entity/Q10971235'),
#   ('homogenate', 'http://www.wikidata.org/entity/Q41771839'),
#   ('ftld', 'http://www.wikidata.org/entity/Q18579'),
#   ('sarkosyl', 'http://www.wikidata.org/entity/Q54327734'),
#   ('omv', 'http://www.wikidata.org/entity/Q168238'),
#   ('biochemical', 'http://www.wikidata.org/entity/Q864221'),
#   ('brain', 'http://www.wikidata.org/entity/Q1073'),
#   ('solubilization', 'http://www.wikidata.org/entity/Q907920')],
#  [('slice', 'http://www.wikidata.org/entity/Q419057'),
#   ('chamber', 'http://www.wikidata.org/entity/Q180516'),
#   ('micropump', 'http://www.wikidata.org/entity/Q1933964'),
#   ('mouse', 'http://www.wikidata.org/entity/Q83310'),
#   ('acsf', 'http://www.wikidata.org/entity/Q24778882'),
#   ('synaptic', 'http://www.wikidata.org/entity/Q213057'),
#   ('interface', 'http://www.wikidata.org/entity/Q23808'),
#   ('circuit', 'http://www.wikidata.org/entity/Q132629'),
#   ('recording', 'http://www.wikidata.org/entity/Q13557414'),
#   ('connect', 'http://www.wikidata.org/entity/Q23009459')],
#  [('fiber', 'http://www.wikidata.org/entity/Q161'),
#   ('odor', 'http://www.wikidata.org/entity/Q33302'),
#   ('food', 'http://www.wikidata.org/entity/Q2095'),
#   ('implant', 'http://www.wikidata.org/entity/Q486975'),
#   ('ubiquitylation', 'http://www.wikidata.org/entity/Q36251951'),
#   ('optic', 'http://www.wikidata.org/entity/Q19832917'),
#   ('mouse', 'http://www.wikidata.org/entity/Q83310'),
#   ('skull', 'http://www.wikidata.org/entity/Q13147'),
#   ('behavior', 'http://www.wikidata.org/entity/Q9332'),
#   ('odorant', 'http://www.wikidata.org/entity/Q485537')],
#  [('tumor', 'http://www.wikidata.org/entity/Q133212'),
#   ('metabolite', 'http://www.wikidata.org/entity/Q407595'),
#   ('primer', 'http://www.wikidata.org/entity/Q334828'),
#   ('protein', 'http://www.wikidata.org/entity/Q8054'),
#   ('fluid', 'http://www.wikidata.org/entity/Q11435'),
#   ('tif', 'http://www.wikidata.org/entity/Q215106'),
#   ('standard', 'http://www.wikidata.org/entity/Q317623'),
#   ('antibody', 'http://www.wikidata.org/entity/Q79460'),
#   ('sample', 'http://www.wikidata.org/entity/Q485146'),
#   ('reaction', 'http://www.wikidata.org/entity/Q36534')],
#  [('cell', 'http://www.wikidata.org/entity/Q7868'),
#   ('macrophage', 'http://www.wikidata.org/entity/Q184204'),
#   ('embryo', 'http://www.wikidata.org/entity/Q33196'),
#   ('solution', 'http://www.wikidata.org/entity/Q5447188'),
#   ('medium', 'http://www.wikidata.org/entity/Q340169'),
#   ('culture', 'http://www.wikidata.org/entity/Q11042'),
#   ('tube', 'http://www.wikidata.org/entity/Q1318740'),
#   ('incubate', 'http://www.wikidata.org/entity/Q48889'),
#   ('test', 'http://www.wikidata.org/entity/Q4115189'),
#   ('PBS', 'http://www.wikidata.org/entity/Q215616')],
#  [('cell', 'http://www.wikidata.org/entity/Q7868'),
#   ('tube', 'http://www.wikidata.org/entity/Q1318740'),
#   ('liver', 'http://www.wikidata.org/entity/Q9368'),
#   ('centrifuge', 'http://www.wikidata.org/entity/Q191134'),
#   ('tissue', 'http://www.wikidata.org/entity/Q40397'),
#   ('medium', 'http://www.wikidata.org/entity/Q340169'),
#   ('supernatant', 'http://www.wikidata.org/entity/Q40307811'),
#   ('aorta', 'http://www.wikidata.org/entity/Q101004'),
#   ('solution', 'http://www.wikidata.org/entity/Q5447188'),
#   ('mouse', 'http://www.wikidata.org/entity/Q83310')],
#  [('plate', 'http://www.wikidata.org/entity/Q57216'),
#   ('root', 'http://www.wikidata.org/entity/Q111029'),
#   ('plant', 'http://www.wikidata.org/entity/Q756'),
#   ('mutation', 'http://www.wikidata.org/entity/Q42918'),
#   ('colony', 'http://www.wikidata.org/entity/Q133156'),
#   ('solution', 'http://www.wikidata.org/entity/Q5447188'),
#   ('model', 'http://www.wikidata.org/entity/Q4610556'),
#   ('tube', 'http://www.wikidata.org/entity/Q1318740'),
#   ('myofiber', 'http://www.wikidata.org/entity/Q14864236'),
#   ('soil', 'http://www.wikidata.org/entity/Q36133')]]

# %% [markdown]
# ## Obtaining each topic's graphs
# In this phase we are going to explore the neighbourhood of each term linked before, to obtain a graph with their related terms from Wikidata. Each set of terms obtained before will be the seed concepts used to obtain the final graph, and a set of properties from Wikidata will be explored recursively to expand the final graph.
#
# For more information about the implementation of the graph building process, the class used can be accessed at the _graph.py_ module in the source directory.
#
# In the following cell we will be configuring the graph builder to build a graph with a maxium depth of two from every seed node. Higher depth values might cause the resulting topic labels to be very general, while with a smaller value we have the risk of not obtaining a connection between the seed nodes:

# %%
from herc_common.graph import WikidataGraphBuilder

graph_builder = WikidataGraphBuilder(max_hops=2)
topic_graphs = [graph_builder.build_graph(topic) for topic in linked_terms]
# Out:
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.

# %% [markdown]
# Now that we have obtained the neighbourhood graph of each topic, we are going to plot the results using bokeh. Each node will have a different color depending on their depth with respect to the seed nodes, which will be painted in blue. This will allow us to perform an initial exploration of these graphs:

# %%
from bokeh.io import show
from bokeh.layouts import gridplot

from herc_common.bokeh_utils import build_graph_plot


plots = [build_graph_plot(g, f"Topic {idx}") 
         for idx, g in enumerate(topic_graphs)]
grid = gridplot(plots, ncols=2)
show(grid)
# Out:
#   <div class="bk-root" id="f4960d80-a3c8-4c68-b1e1-0b4e89805424" data-root-id="1632"></div>

# %% [markdown]
# An optimum result would be to have every seed term connected in the final graph. However, theere will be some subgraphs which are isolated from the main ones. In the following section we will be solving this issue.

# %% [markdown]
# ## Getting the main connected subgraph
# As we have described before, some of the topic graphs that we have obtained are not fully connected. Small subgraphs which are isolated from the main subgraph will be considered as noise, and removed before the following computations.
#
# In the following cells, we are going to retrieve the largest connected subgraph from each topic's graph, and plot the results to anaylise them:

# %%
from herc_common.graph import get_largest_connected_subgraph

connected_topic_subgraphs = [get_largest_connected_subgraph(g) 
                             for g in topic_graphs]

# %%
plots = [build_graph_plot(g, f"Largest Connected subgraph for topic {idx}") 
         for idx, g in enumerate(connected_topic_subgraphs)]
grid = gridplot(plots, ncols=2)
show(grid)
# Out:
#   <div class="bk-root" id="4ee22b2e-e371-479d-b9c6-aa168c80a0fb" data-root-id="3869"></div>

# %% [markdown]
# In this section we are aiming to see big graphs with the most amount of seed nodes possible. Graphs with few seed nodes from the original term distribution will tend to be less representative of the original topic.

# %% [markdown]
# ## Obtaining the main component of each topic
# Now that we have the final subgraph for each topic, we will be applying several centrality measures to obtain the node that best represents the topic. In the following cell we have defined an auxiliary function that receives a list of algorithm and returns the results of applying them to obtain the best _n_ entities that represent each topic:

# %%
import networkx.algorithms as nxa

from herc_common.graph import get_centrality_algorithm_results

def try_centrality_algorithms(topic_subgraphs, algorithms, stop_uris, top_n=4):
    markdown = ""
    for (algorithm, name) in algorithms:
        print(f'Algorithm: {name}')
        results = [get_centrality_algorithm_results(g, algorithm, stop_uris, top_n)
                   for g in topic_subgraphs]
        results_labels = [[(node[0]['label'], node[1]) for node in topic] 
                          for topic in results]
        for idx, result in enumerate(results_labels):
            print(f"Topic {idx}:", result)
            print()
        print()

        
algorithms = [
    (nxa.centrality.information_centrality, "Information centrality"),
    (nxa.centrality.eigenvector_centrality_numpy, "Eigenvector centrality"),
    (nxa.centrality.closeness_centrality, "Closeness centrality"),
    (nxa.centrality.betweenness_centrality, "Betweenness centrality"),
    (nxa.centrality.communicability_betweenness_centrality, "Communicability betweenness centrality")
]

try_centrality_algorithms(connected_topic_subgraphs,
                          algorithms,
                          ['Q4167836', 'Q11862829'])
# Out:
# Algorithm: Information centrality
# Topic 0: [('anatomical structure', 0.004410230503542343), ('tissue', 0.0043912401684426915), ('bone', 0.00421948126950598), ('organ', 0.0042057973884043415)]
#
# Topic 1: [('interaction science', 0.0033325948347372784), ('communication medium', 0.0031963122684946976), ('culture', 0.003156169122509699), ('anthropology', 0.0031138305482050392)]
#
# Topic 2: [('protein', 0.0026568746129703616), ('biological process', 0.0025560791767436307), ('group or class of chemical substances', 0.0024574656720053926), ('biopolymer', 0.002444347212892366)]
#
# Topic 3: [('gene', 0.026058631921824105), ('genome', 0.025559105431309924), ('chromosome', 0.024615384615384615), ('DNA', 0.020253164556962026)]
#
# Topic 4: [('brain', 0.0049438776038548534), ('neuroscience', 0.004755781587231344), ('brain stem', 0.004616296866095642), ('rhombencephalon', 0.004559329159101296)]
#
# Topic 5: [('protein', 0.018965010291090868), ('first-order metaclass', 0.014939200926462058), ('Magnesium-protoporphyrin IX monomethyl ester [oxidative] cyclase', 0.014322193849228358), ('protein family', 0.013811563169164875)]
#
# Topic 6: [('food', 0.0045662100456620915), ('disposable product', 0.004444444444444442), ('product', 0.004219409282700417), ('eating', 0.004073319755600807)]
#
# Topic 7: [('protein', 0.004274603735946243), ('biological process', 0.0040677764754572755), ('group or class of chemical substances', 0.0038953407676343256), ('biopolymer', 0.003817125676397797)]
#
# Topic 8: [('interaction science', 0.002338547754702097), ('communication medium', 0.002303900609224414), ('culture', 0.002221289658668482), ('media history', 0.0022143781734606962)]
#
# Topic 9: [('cell', 0.0017657702930787109), ('biological component', 0.0017545457267280188), ('anatomical structure', 0.0017465496169098884), ('tissue', 0.0017225243615765886)]
#
# Topic 10: [('botany', 0.0029749931974240944), ('plant', 0.0027979579322809935), ('soil', 0.002767693433280036), ('pedology', 0.002767468153767206)]
#
#
# Algorithm: Eigenvector centrality
# Topic 0: [('tissue', 0.449849629480173), ('anatomical structure', 0.4294703448248451), ('organ', 0.34309871813997456), ('biological component', 0.2961435819179446)]
#
# Topic 1: [('interaction science', 0.6752603894858923), ('communication', 0.20623257719656432), ('communication medium', 0.18498580028136546), ('communication studies', 0.14598236021284336)]
#
# Topic 2: [('protein', 0.5287141946022671), ('biological process', 0.378995526091614), ('establishment of protein localization to spindle pole body', 0.18582511907219051), ('regulation protein catabolic process at synapse', 0.1810370058435665)]
#
# Topic 3: [('genome', 0.5405463005108783), ('chromosome', 0.43228541475182436), ('gene', 0.40356368394703135), ('DNA', 0.24334997640562384)]
#
# Topic 4: [('brain', 0.4611331844896117), ('brain stem', 0.35713816798428355), ('rhombencephalon', 0.3241134592084416), ('encephalon', 0.26863597690538366)]
#
# Topic 5: [('protein', 0.701244467312443), ('first-order metaclass', 0.14994491236940347), ('Magnesium-protoporphyrin IX monomethyl ester [oxidative] cyclase', 0.1442582349374386), ('regulation protein catabolic process at synapse', 0.12321961484011827)]
#
# Topic 6: [('textile', 0.5769305326734058), ('base material', 0.40329436421370357), ('fiber', 0.3391072672854361), ('product', 0.19942608253043623)]
#
# Topic 7: [('protein', 0.5327745545118849), ('biological process', 0.3715867117056011), ('establishment of protein localization to spindle pole body', 0.18320302025612706), ('regulation protein catabolic process at synapse', 0.17856126377253956)]
#
# Topic 8: [('interaction science', 0.6782405706056222), ('communication', 0.2077682557873171), ('communication medium', 0.18548786625893615), ('communication studies', 0.14702218607027542)]
#
# Topic 9: [('interaction science', 0.6845122562670062), ('communication', 0.21091020673178215), ('communication medium', 0.1854519978745801), ('communication studies', 0.1492548713120572)]
#
# Topic 10: [('botany', 0.6181637377655895), ('plant', 0.3159712901205122), ('plant genetics', 0.2368593640827487), ('organism', 0.18719965625209903)]
#
#
# Algorithm: Closeness centrality
# Topic 0: [('tissue', 0.26101694915254237), ('anatomical structure', 0.25496688741721857), ('organ', 0.24367088607594936), ('multicellular structure', 0.2361963190184049)]
#
# Topic 1: [('interaction science', 0.30857142857142855), ('media history', 0.28471001757469244), ('communication medium', 0.28421052631578947), ('cell biology', 0.28125)]
#
# Topic 2: [('protein', 0.2955665024630542), ('ribonucleoprotein', 0.2777777777777778), ('ribonucleoprotein granule', 0.27149321266968324), ('group or class of chemical substances', 0.26277372262773724)]
#
# Topic 3: [('gene', 0.574468085106383), ('genome', 0.5510204081632653), ('chromosome', 0.5192307692307693), ('biological sequence', 0.4090909090909091)]
#
# Topic 4: [('brain', 0.32954545454545453), ('neuroscience', 0.31985294117647056), ('biology', 0.28618421052631576), ('brain stem', 0.2676923076923077)]
#
# Topic 5: [('protein', 0.6666666666666666), ('first-order metaclass', 0.5176470588235295), ('Magnesium-protoporphyrin IX monomethyl ester [oxidative] cyclase', 0.4631578947368421), ('protein catabolic process at presynapse', 0.4036697247706422)]
#
# Topic 6: [('food', 0.30165289256198347), ('disposable product', 0.29435483870967744), ('product', 0.28076923076923077), ('eating', 0.26258992805755393)]
#
# Topic 7: [('protein', 0.4318181818181818), ('first-order metaclass', 0.3543123543123543), ('group or class of chemical substances', 0.3431151241534989), ('biopolymer', 0.3415730337078652)]
#
# Topic 8: [('interaction science', 0.24862637362637363), ('cytology', 0.24693042291950887), ('cell', 0.2449255751014885), ('communication medium', 0.2381578947368421)]
#
# Topic 9: [('biological component', 0.23572170301142265), ('tissue', 0.22542204568023833), ('cell', 0.22386587771203156), ('anatomical structure', 0.22233104799216455)]
#
# Topic 10: [('botany', 0.2599118942731278), ('pedology', 0.24737945492662475), ('soil science', 0.24532224532224534), ('plant', 0.24279835390946503)]
#
#
# Algorithm: Betweenness centrality
# Topic 0: [('anatomical structure', 0.43828890407837795), ('tissue', 0.42245386192754614), ('group of cells', 0.3961038961038961), ('group', 0.3629528366370472)]
#
# Topic 1: [('interaction science', 0.410423170878658), ('cell biology', 0.26619891112644734), ('information technology', 0.25512321944344046), ('computer hardware', 0.22840747678566886)]
#
# Topic 2: [('protein', 0.6490512911462623), ('cellular component', 0.33729594841326704), ('biological component', 0.33596279849538724), ('component', 0.3081315952824333)]
#
# Topic 3: [('gene', 0.6068376068376069), ('genome', 0.5299145299145299), ('chromosome', 0.358974358974359), ('gene cluster', 0.1452991452991453)]
#
# Topic 4: [('brain', 0.6823993168018829), ('neuroscience', 0.5900828655439722), ('biochemistry', 0.4601710772520716), ('Biochemical Journal', 0.3581929965249933)]
#
# Topic 5: [('protein', 0.9054792107117688), ('first-order metaclass', 0.3092847075405215), ('taxon', 0.18613460183227615), ('protein family', 0.18243481324876684)]
#
# Topic 6: [('food', 0.6974885844748858), ('disposable product', 0.526255707762557), ('product', 0.5167427701674276), ('eating', 0.3944063926940639)]
#
# Topic 7: [('protein', 0.7565252120367143), ('amino acid', 0.30280585569884977), ('chemical substance', 0.14891222260950399), ('peptide bond', 0.1404888462879052)]
#
# Topic 8: [('cell', 0.4333896050746886), ('interaction science', 0.38071750124236303), ('cytology', 0.3411616825981472), ('communication medium', 0.28264126399485506)]
#
# Topic 9: [('interaction science', 0.33068913313933), ('artery system', 0.31250847013585314), ('anatomical structure', 0.31161421118440347), ('cytology', 0.3047229052141148)]
#
# Topic 10: [('botany', 0.6308368342266645), ('soil', 0.5406586508281421), ('plant', 0.46875754502873224), ('pedology', 0.2919986479308514)]
#
#
# Algorithm: Communicability betweenness centrality
# Topic 0: [('anatomical structure', 0.5117284326534308), ('tissue', 0.4907690147218937), ('group of cells', 0.4056154078966122), ('group', 0.3642810035339426)]
#
# Topic 1: [('interaction science', 0.46251690248241056), ('cell biology', 0.2941331391339292), ('information technology', 0.25008067151887703), ('cell', 0.23571269406750006)]
#
# Topic 2: [('protein', 0.7211991388952644), ('biological component', 0.3560045889562504), ('cellular component', 0.33374908547938814), ('component', 0.3090089478918254)]
#
# Topic 3: [('gene', 0.68571012597752), ('genome', 0.6276329603000468), ('chromosome', 0.4882492206747225), ('Nucleic acid sequence', 0.20934843688279697)]
#
# Topic 4: [('brain', 0.7152815392878625), ('neuroscience', 0.5990821447593779), ('biochemistry', 0.46329092048142395), ('Biochemical Journal', 0.3638608152378348)]
#
# Topic 5: [('protein', 0.9157992672388943), ('first-order metaclass', 0.3621135433576234), ('protein family', 0.21291100785783723), ('taxon', 0.19490195341316174)]
#
# Topic 6: [('food', 0.7036600243952064), ('disposable product', 0.5339346585172436), ('product', 0.5248555936254701), ('eating', 0.4058238087664998)]
#
# Topic 7: [('protein', 0.8430490960043795), ('amino acid', 0.31845855991979727), ('biological process', 0.23761885166873176), ('biopolymer', 0.20181041633193766)]
#
# Topic 8: [('cell', 0.45081647806782876), ('interaction science', 0.4181806222549147), ('cytology', 0.34722973586188294), ('communication medium', 0.30382100643823334)]
#
# Topic 9: [('anatomical structure', 0.3540850298098629), ('interaction science', 0.34531306878824836), ('artery system', 0.3237375806185072), ('biological component', 0.3097831927400156)]
#
# Topic 10: [('botany', 0.6468655030911954), ('soil', 0.5653548744688814), ('plant', 0.49378888881558586), ('pedology', 0.34460025754797885)]

# %% [markdown]
# ## Add labels to LDA model
# Finally, we will be saving the best results to our LDA model that has been trained previously. Now, when we load the model again, after a topic has been inferred for a given text we will also be able to return a representative label for the topic, which will be also linked to Wikidata:

# %%
from herc_common.topic import Topic

final_results = [get_centrality_algorithm_results(g,
                                                  nxa.centrality.information_centrality,
                                                  ['Q4167836', 'Q11862829'], top_n=1)
                 for g in connected_topic_subgraphs]

final_results_topics = [Topic.from_node(topic[0], topic[1], "lda") 
                        for result in final_results for topic in result]
lda_model = lda_pipe.named_steps['model']

# %%
from tqdm import tqdm

import en_core_sci_lg
import string
import numpy as np

en_core_sci_lg.load()

# %%
from herc_common.topic import LabelledTopicModel

labelled_topic_model = LabelledTopicModel(lda_model, final_results_topics)

lda_pipe.steps.pop()
lda_pipe.steps.append(('model', labelled_topic_model))

# %%
from herc_common.utils import save_object

save_object(lda_pipe, os.path.join(NOTEBOOK_4_RESULTS_DIR, 'lda_pipe_with_labels.pkl'))

# %% [markdown]
# ## Obtaining the results for every article in the dataset

# %%
results = lda_pipe.transform(protocols)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %% [markdown]
# ## Saving the results

# %%
NEW_COL_NAME = 'topics_from_lda'

df[NEW_COL_NAME] = ['\n'.join([f"{topic.label}, {topic.score:.5f}" for topic in result])
                        for result in results]
df.head()

results_df = df[['pr_id', 'title', NEW_COL_NAME]]
results_df.head()
# Out:
#    pr_id                                              title  \
# 0   e100                        Scratch Wound Healing Assay
# 1  e1029                                ADCC Assay Protocol
# 2  e1072        Catalase Activity Assay in Candida glabrata
# 3  e1077           RNA Isolation and Northern Blot Analysis
# 4  e1090  Flow Cytometric Analysis of Autophagic Activit...
#
#                                      topics_from_lda
# 0  interaction science, 0.99548\ninteraction scie...
# 1  protein, 0.74729\ninteraction science, 0.25011...
# 2  botany, 0.62093\nprotein, 0.31150\ninteraction...
# 3  protein, 0.42861\nprotein, 0.29078\nanatomical...
# 4  interaction science, 0.99796\ninteraction scie...

# %%
OUTPUT_FILE_NAME = "protocols_df_with_lda_topics.csv"

results_df.to_csv(os.path.join(NOTEBOOK_5_RESULTS_DIR, OUTPUT_FILE_NAME), index=False)
