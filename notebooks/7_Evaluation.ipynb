# %% [markdown]
# # 7. Evaluation of results
# In this final notebook we will propose an evaluation metric to check the performance and our final systems on the protocols track. For our approach we will rely on the default categories asigned to each protocols. For an additional level of accuracy in the evaluation of our models, the list of subjects used as ground truth could be generated by a human committee. For the scope of this challenge, we will however rely on the default subjects present in each protocol and leave the human annotation as future work.

# %% [markdown]
# ## Setup

# %%
# %run __init__.py
# Out:
# INFO:root:Starting logger

# %%
import pandas as pd

PROTOCOLS_FILE_PATH = os.path.join(NOTEBOOK_2_RESULTS_DIR, 'protocols_dataframe.pkl')

protocols_df = pd.read_pickle(PROTOCOLS_FILE_PATH)

# %% [markdown]
# ## Analyzing the categories
# We will begin by selecting a subset of the protocols dataframe with just the id of the protocol and its categories:

# %%
import numpy as np

categories_df = protocols_df.copy()
categories_df['categories'].replace('', np.nan, inplace=True)
categories_df.dropna(subset=['categories'], inplace=True)
categories_df.head(n=4)
# Out:
#    pr_id                                        title  \
# 0   e100                  Scratch Wound Healing Assay
# 1  e1029                          ADCC Assay Protocol
# 2  e1072  Catalase Activity Assay in Candida glabrata
# 3  e1077     RNA Isolation and Northern Blot Analysis
#
#                                             abstract  \
# 0  The scratch wound healing assay has been widel...
# 1  Antibody-dependent cell-mediated cytotoxicity ...
# 2  Commensal and pathogenic fungi are exposed to ...
# 3  The northern blot is a technique used in molec...
#
#                                            materials  \
# 0  Human MDA-MB-231 cell line (ATCC, catalog numb...
# 1  Raji cells (ATCC)|A/California/04/2009 (H1N1) ...
# 2  Yeast strains \nNote: BG14 was used as the C. ...
# 3  Vero cells (kidney epithelial cells extracted ...
#
#                                            procedure  \
# 0  Grow cells in DMEM supplemented with 10% FBS.|...
# 1  Preperation of Target Cells\n\n\t\t\n\n\n\t\t\...
# 2  Preparation of total soluble extracts\n\t\t\n\...
# 3  RNA extraction\n\t\t\n\n\t\t\t\tCells were see...
#
#                                            equipment background  \
# 0  BD Falcon 24-well tissue culture plate (Fisher...
# 1  Round bottomed 96-well plate|Temperature contr...
# 2  Orbital incubator shaker|Microfuge tubes|50 ml...
# 3  100 mm cell culture dishes (Corning, catalog n...
#
#                                           categories  \
# 0  Cancer Biology|Invasion & metastasis|Cell biol...
# 1  Immunology|Immune cell function|Cytotoxicity|C...
# 2  Microbiology|Microbial biochemistry|Protein|Ac...
# 3  Microbiology|Microbial genetics|RNA|RNA extrac...
#
#                                              authors  \
# 0                                       Yanling Chen
# 1  Vikram  Srivastava|Zheng  Yang|Ivan  Fan  Ngai...
# 2  Emmanuel  Orta-Zavalza|Marcela  Briones-Martin...
# 3  Ying Liao|To Sing Fung|Mei Huang|Shouguo Fang|...
#
#                                            full_text  \
# 0  Scratch Wound Healing Assay. The scratch wound...
# 1  ADCC Assay Protocol. Antibody-dependent cell-m...
# 2  Catalase Activity Assay in Candida glabrata. C...
# 3  RNA Isolation and Northern Blot Analysis. The ...
#
#                                full_text_no_abstract  \
# 0  Scratch Wound Healing Assay. Grow cells in DME...
# 1  ADCC Assay Protocol. Preperation of Target Cel...
# 2  Catalase Activity Assay in Candida glabrata. P...
# 3  RNA Isolation and Northern Blot Analysis. RNA ...
#
#                                    full_text_cleaned  \
# 0  Scratch Wound Healing Assay. The scratch wound...
# 1  ADCC Assay Protocol. Antibody-dependent cell-m...
# 2  Catalase Activity Assay in Candida glabrata. C...
# 3  RNA Isolation and Northern Blot Analysis. The ...
#
#                        full_text_no_abstract_cleaned  num_chars_text
# 0  Scratch Wound Healing Assay. Grow cells in DME...            2583
# 1  ADCC Assay Protocol. Preperation of Target Cel...            3824
# 2  Catalase Activity Assay in Candida glabrata. P...            4207
# 3  RNA Isolation and Northern Blot Analysis. RNA ...            6890

# %%
protocols_categories = {aid: categories.split('|') 
                       for aid, categories in zip(categories_df['pr_id'].values,
                                                  categories_df['categories'].values)}
protocols_categories['e1029']
# Out:
# ['Immunology',
#  'Immune cell function',
#  'Cytotoxicity',
#  'Cell Biology',
#  'Cell-based analysis',
#  'Flow cytometry']

# %% [markdown]
# As we can see above, each protocol is composed of a variable sized list of category terms.
#
# In the following cell we are going to perform a cleaning of the categories to remove those that will not be useful for the evaluation of our models. We will remove those words that do not have a match to WordNet, which will be used later on to perform the evaluation of the models. Finally, those rows that do not have any caetgory will be removed from the final sample:

# %%
from herc_common.evaluation import _get_synset

stop_categories = set([])

filtered_protocols_categories = {
    k: set([el for el in v if el.lower() not in stop_categories
            and not el.isnumeric() and _get_synset(el) is not None])
    for k, v in protocols_categories.items()
}

final_protocols_categories = {
    k: v
    for k, v in filtered_protocols_categories.items()
    if len(v) != 0
}

len(final_protocols_categories)
# Out:
# 94

# %%
final_protocols_categories
# Out:
# {'e1029': {'Cytotoxicity', 'Immunology'},
#  'e1072': {'Activity', 'Biochemistry', 'Microbiology', 'Protein'},
#  'e1077': {'Microbiology', 'Molecular Biology', 'RNA'},
#  'e1090': {'Microbiology'},
#  'e1136': {'Biochemistry', 'Microbiology', 'Protein'},
#  'e1180': {'Cytokine', 'Immunology', 'Macrophage'},
#  'e1183': {'Development', 'Ligand', 'Stem Cell'},
#  'e122': {'Biochemistry', 'Immunology', 'Protein'},
#  'e1235': {'General', 'Immunology', 'Microbiology'},
#  'e1236': {'Biochemistry', 'Carbohydrate', 'Glycoprotein', 'Polysaccharide'},
#  'e1287': {'Biochemistry', 'Microbiology', 'Protein'},
#  'e1295': {'Microbiology', 'Virus'},
#  'e1308': {'Microbiology'},
#  'e1374': {'Biochemistry',
#   'Detection',
#   'Molecular Biology',
#   'Protein',
#   'Synthesis'},
#  'e1428': {'Microbiology', 'Molecular Biology', 'RNA'},
#  'e144': {'Stem Cell'},
#  'e1467': {'Biochemistry', 'Carotenoid', 'Chlorophyll', 'Microbiology'},
#  'e1471': {'Immunology'},
#  'e1569': {'Bacterium', 'Microbiology'},
#  'e16': {'Microbiology'},
#  'e162': {'Morphogenesis'},
#  'e172': {'DNA', 'Molecular Biology'},
#  'e1797': {'Metamorphosis', 'Morphogenesis'},
#  'e186': {'Biochemistry', 'Carbohydrate', 'Glycogen'},
#  'e187': {'Cell death'},
#  'e191': {'Morphogenesis', 'Neuroscience'},
#  'e1912': {'Biochemistry', 'Lipid'},
#  'e195': {'Nucleic acid'},
#  'e2045': {'Angiogenesis'},
#  'e212': {'Activity',
#   'Biochemistry',
#   'Expression',
#   'Microbiology',
#   'Molecular Biology',
#   'Protein'},
#  'e2273': {'Microbiology', 'Transport'},
#  'e235': {'Neuroscience'},
#  'e247': {'Cell death'},
#  'e250': {'Biochemistry', 'Interaction', 'Microbiology', 'Protein'},
#  'e2505': {'Activity', 'Biochemistry', 'Microbiology', 'Protein'},
#  'e251': {'Biochemistry', 'Microbiology', 'Protein'},
#  'e252': {'Microbiology'},
#  'e260': {'Angiogenesis'},
#  'e261': {'Angiogenesis'},
#  'e263': {'Biochemistry'},
#  'e2763': {'DNA', 'Microbiology', 'Molecular Biology', 'Mutagenesis'},
#  'e3089': {'Immunology', 'Mammal', 'Microbiology', 'Mouse'},
#  'e3097': {'Genomics'},
#  'e313': {'Biochemistry'},
#  'e314': {'Glial cell', 'Immunology'},
#  'e322': {'Immunology', 'Lymphocyte'},
#  'e323': {'Immunology', 'Lymphocyte'},
#  'e325': {'Self-renewal'},
#  'e327': {'Development', 'Neuron', 'Neuroscience'},
#  'e3295': {'Regeneration', 'Stem Cell'},
#  'e3298': {'Electron microscopy'},
#  'e3303': {'Microbiology', 'Proteomics'},
#  'e3312': {'Molecular Biology', 'Neuroscience', 'RNA', 'Stem Cell'},
#  'e3313': {'Stem Cell'},
#  'e332': {'Development',
#   'Immunofluorescence',
#   'Morphogenesis',
#   'Neuroscience'},
#  'e3327': {'Cell wall'},
#  'e3344': {'Cell wall', 'Microbiology'},
#  'e3350': {'Myelin', 'Neuroscience', 'Stem Cell'},
#  'e3355': {'DNA', 'Molecular Biology', 'Phycology', 'Transformation'},
#  'e3382': {'DNA', 'Molecular Biology', 'Neuroscience'},
#  'e3386': {'Morphogenesis', 'Stem Cell'},
#  'e3387': {'Neuroscience'},
#  'e3393': {'Mouse', 'Neuroscience'},
#  'e3397': {'Neuroscience'},
#  'e3398': {'Cell wall'},
#  'e3399': {'Leaf', 'Metabolite'},
#  'e3402': {'Fluorescence', 'Metabolism', 'Nutrition'},
#  'e3406': {'Neuroscience'},
#  'e3407': {'Genomics', 'Microbiology', 'Screening'},
#  'e3408': {'Biochemistry', 'Imaging', 'Neuroscience', 'Protein'},
#  'e3415': {'Microbiology', 'Molecular Biology', 'RNA'},
#  'e3417': {'Differentiation', 'Stem Cell'},
#  'e3420': {'Molecular Biology', 'Protein'},
#  'e3424': {'Biochemistry',
#   'Detection',
#   'Molecular Biology',
#   'Neuroscience',
#   'Protein'},
#  'e3430': {'Biochemistry', 'Molecular Biology', 'Protein'},
#  'e3433': {'Molecular Biology', 'RNA'},
#  'e3434': {'Fungus', 'Microbiology'},
#  'e3435': {'DNA', 'Molecular Biology'},
#  'e3436': {'Development', 'Neuroscience'},
#  'e431': {'Biochemistry'},
#  'e49': {'Microbiology'},
#  'e68': {'Immunology'},
#  'e689': {'Immunology', 'Lymphocyte'},
#  'e754': {'Biochemistry', 'Fractionation', 'Protein'},
#  'e786': {'Fluorescence', 'Morphogenesis'},
#  'e834': {'Cytokine', 'Immunology'},
#  'e859': {'Immunology'},
#  'e888': {'Biochemistry', 'Microbiology', 'Protein'},
#  'e928': {'Activity',
#   'Biochemistry',
#   'Interaction',
#   'Modification',
#   'Protein'},
#  'e954': {'Immunology', 'Microbiology', 'Mouse'},
#  'e959': {'Fluorescence', 'Microbiology'},
#  'e976': {'Immunology', 'Macrophage'},
#  'e977': {'Cytokine', 'Immunology', 'Mammal', 'Microbiology'},
#  'e995': {'Biochemistry', 'Lipid', 'Microbiology'}}

# %% [markdown]
# As we can see above, from the initial 100 protocols in the dataframe 96 have at least a category to be compared against.

# %% [markdown]
# ## Evaluation
# For the evaluation of our system we will use WordNet to obtain a semantic similarity score between the topics predicted by our system and those used as ground truth.
#
# Before we can start calculating these similarity scores, we will obtain the topics predicted by our system. First, we will be loading the final pipeline that has been saved in our previous notebook:

# %%
import string

import en_core_sci_lg
import en_core_web_md

from collections import Counter

from tqdm import tqdm

en_core_web_md.load()
en_core_sci_lg.load()

# %%
from herc_common.utils import load_object

final_pipe = load_object(os.path.join(NOTEBOOK_6_RESULTS_DIR, 'final_pipe.pkl'))

# %% [markdown]
# Now, we will select the sample of publications with at least one ground truth subject, and obtain the output of our system for those articles:

# %%
protocols_keys = final_protocols_categories.keys()
X = categories_df.set_index('pr_id', inplace=False).loc[protocols_keys]['full_text_cleaned'].values

# %%
y_base = final_protocols_categories.values()
y_pred = final_pipe.transform(X)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=94.0), HTML(value='')))
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# INFO:herc_common.graph:Started building graph.
# INFO:herc_common.graph:Finished building graph.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
y_pred = [[str(topic[0]) for topic in doc] for doc in y_pred]
y_pred[:5]
# Out:
# [['protein',
#   'biological process',
#   'process',
#   'carbon dioxide transmembrane transport',
#   'death',
#   'response to carbon dioxide',
#   'cellular response to carbon dioxide'],
#  ['botany',
#   'protein',
#   'chemistry',
#   'chemical compound',
#   'chemical substance',
#   'group or class of proteins',
#   'cell type'],
#  ['protein',
#   'biological process',
#   'process',
#   'chemical compound',
#   'chemistry',
#   'chemical substance',
#   'science'],
#  ['process',
#   'chemical compound',
#   'biological process',
#   'glucose',
#   'concept',
#   'interaction science',
#   'intentional human action'],
#  ['interaction science',
#   'protein',
#   'chemical compound',
#   'materials science',
#   'technology',
#   'cell biology',
#   'biopolymer']]

# %% [markdown]
# ## Similarity
# In this section we will be calculating the similarity scores between the topics inferred by the model and the ones used as ground truth:

# %%
from herc_common.evaluation import compute_similarity_scores

scores = [compute_similarity_scores(y_b, y_p, 'lch_similarity')
          for y_b, y_p in zip(y_base, y_pred)]
scores[:5]
# Out:
# [{'max similarity': 1.4403615823901665,
#   'min similarity': 0.9295359586241757,
#   'mean similarity': 1.184948770507171,
#   'median similarity': 1.184948770507171},
#  {'max similarity': 3.6375861597263857,
#   'min similarity': 1.55814461804655,
#   'mean similarity': 2.4407132240308744,
#   'median similarity': 2.283561059175281},
#  {'max similarity': 2.538973871058276,
#   'min similarity': 2.0281482472922856,
#   'mean similarity': 2.1984234552142823,
#   'median similarity': 2.0281482472922856},
#  {'max similarity': 1.3350010667323402,
#   'min similarity': 1.3350010667323402,
#   'mean similarity': 1.3350010667323402,
#   'median similarity': 1.3350010667323402},
#  {'max similarity': 3.6375861597263857,
#   'min similarity': 0.8649974374866046,
#   'mean similarity': 1.7891936782331985,
#   'median similarity': 0.8649974374866046}]

# %%
final_similarity = np.mean([score['mean similarity'] for score in scores])
final_similarity
# Out:
# 1.7950689264796515

# %% [markdown]
# ## Saving the results
# Finally, we are going to save the results. First of all, the predictions will be saved to a new dataframe:

# %%
cols_subset = ['title', 'categories']

results_df = categories_df.set_index('pr_id', inplace=False).loc[protocols_keys][cols_subset]
results_df['Topics Predicted'] = ['\n'.join(topics) for topics in y_pred]
results_df['categories'] = ['\n'.join(topics) for topics in y_base]
results_df.head()
# Out:
#                                                    title  \
# pr_id
# e1029                                ADCC Assay Protocol
# e1072        Catalase Activity Assay in Candida glabrata
# e1077           RNA Isolation and Northern Blot Analysis
# e1090  Flow Cytometric Analysis of Autophagic Activit...
# e1136  Preparation of Parasite Protein Extracts and W...
#
#                                           categories  \
# pr_id
# e1029                       Cytotoxicity\nImmunology
# e1072  Microbiology\nActivity\nProtein\nBiochemistry
# e1077           Microbiology\nMolecular Biology\nRNA
# e1090                                   Microbiology
# e1136            Microbiology\nProtein\nBiochemistry
#
#                                         Topics Predicted
# pr_id
# e1029  protein\nbiological process\nprocess\ncarbon d...
# e1072  botany\nprotein\nchemistry\nchemical compound\...
# e1077  protein\nbiological process\nprocess\nchemical...
# e1090  process\nchemical compound\nbiological process...
# e1136  interaction science\nprotein\nchemical compoun...

# %%
scores_df = pd.DataFrame.from_records(scores)
scores_df.set_index(results_df.index, inplace=True)
scores_df.head()
# Out:
#        max similarity  min similarity  mean similarity  median similarity
# pr_id
# e1029        1.440362        0.929536         1.184949           1.184949
# e1072        3.637586        1.558145         2.440713           2.283561
# e1077        2.538974        2.028148         2.198423           2.028148
# e1090        1.335001        1.335001         1.335001           1.335001
# e1136        3.637586        0.864997         1.789194           0.864997

# %% [markdown]
# And now the scores obtained for each protocol will be saved too:

# %%
final_df = results_df.join(scores_df)
final_df.head()
# Out:
#                                                    title  \
# pr_id
# e1029                                ADCC Assay Protocol
# e1072        Catalase Activity Assay in Candida glabrata
# e1077           RNA Isolation and Northern Blot Analysis
# e1090  Flow Cytometric Analysis of Autophagic Activit...
# e1136  Preparation of Parasite Protein Extracts and W...
#
#                                           categories  \
# pr_id
# e1029                       Cytotoxicity\nImmunology
# e1072  Microbiology\nActivity\nProtein\nBiochemistry
# e1077           Microbiology\nMolecular Biology\nRNA
# e1090                                   Microbiology
# e1136            Microbiology\nProtein\nBiochemistry
#
#                                         Topics Predicted  max similarity  \
# pr_id
# e1029  protein\nbiological process\nprocess\ncarbon d...        1.440362
# e1072  botany\nprotein\nchemistry\nchemical compound\...        3.637586
# e1077  protein\nbiological process\nprocess\nchemical...        2.538974
# e1090  process\nchemical compound\nbiological process...        1.335001
# e1136  interaction science\nprotein\nchemical compoun...        3.637586
#
#        min similarity  mean similarity  median similarity
# pr_id
# e1029        0.929536         1.184949           1.184949
# e1072        1.558145         2.440713           2.283561
# e1077        2.028148         2.198423           2.028148
# e1090        1.335001         1.335001           1.335001
# e1136        0.864997         1.789194           0.864997

# %%
final_df.to_csv(os.path.join(NOTEBOOK_7_RESULTS_DIR, 'protocols_scores.csv'))
